# %% [markdown]
# # Quickstart
# Now that you installation went ok, let's start with a small example.
# Let's create our first `Geodes` object.

# %%
from pygeodes import Geodes

geodes = Geodes()

# %% [markdown]
# ## Searching for collections
# Then we can start by searching for existing collections, for example with search term *sentinel* :

# %%
collections, dataframe = geodes.search_collections("sentinel")
# Out:
# /work/scratch/data/fournih/test_env/lib/python3.11/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexing: 100%|██████████| 111/111 [00:00<00:00, 2032.17it/s]

# %% [markdown]
# Let's see what we found. As a result, we get a `collections` object, which is a list of `Collection` objects.

# %%
collections
# Out:
# [<Collection id=MUSCATE_Snow_SENTINEL2_L2B-SNOW>,
#  <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L2A>,
#  <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L3A>,
#  <Collection id=MUSCATE_WaterQual_SENTINEL2_L2B-WATER>,
#  <Collection id=PEPS_S2_L2A>,
#  <Collection id=PEPS_S2_L1C>,
#  <Collection id=PEPS_S1_L2>,
#  <Collection id=PEPS_S1_L1>,
#  <Collection id=MUSCATE_Snow_MULTISAT_L3B-SNOW>,
#  <Collection id=TAKE5_SPOT4_L1C>,
#  <Collection id=MUSCATE_LANDSAT_LANDSAT8_L2A>,
#  <Collection id=MUSCATE_OSO_RASTER_L3B-OSO>,
#  <Collection id=TAKE5_SPOT4_L2A>,
#  <Collection id=MUSCATE_Snow_LANDSAT8_L2B-SNOW>,
#  <Collection id=PEPS_S3_L1>,
#  <Collection id=TAKE5_SPOT5_L1C>,
#  <Collection id=TAKE5_SPOT5_L2A>,
#  <Collection id=MUSCATE_OSO_VECTOR_L3B-OSO>]

# %% [markdown]
# and a `dataframe` object, which is a `geopandas.GeoDataFrame`.

# %%
dataframe
# Out:
#                                      title  \
# 0               MUSCATE Snow SENTINEL2 L2B
# 1                    MUSCATE SENTINEL2 L2A
# 2                    MUSCATE SENTINEL2 L3A
# 3          MUSCATE WaterQual SENTINEL2 L2B
# 4                PEPS Sentinel-2 L2A tiles
# 5                PEPS Sentinel-2 L1C tiles
# 6                   PEPS Sentinel-1 Level2
# 7                   PEPS Sentinel-1 Level1
# 8                         MUSCATE L3B Snow
# 9                      TAKE5 SPOT4 LEVEL1C
# 10                    MUSCATE LANDSAT8 L2A
# 11                      MUSCATE OSO RASTER
# 12                     TAKE5 SPOT4 LEVEL2A
# 13               MUSCATE Snow LANDSAT8 L2B
# 14  GDH Sentinel-3 L1 STM Level-1 products
# 15                     TAKE5 SPOT5 LEVEL1C
# 16                     TAKE5 SPOT5 LEVEL2A
# 17                      MUSCATE OSO VECTOR
#
#                                           description  \
# 0   Theia Snow product is generated from Sentinel-...
# 1   The level 2A products correct the data for atm...
# 2   The products of level 3A provide a monthly syn...
# 3   The processing chain outputs rasters of the co...
# 4   Sentinel-2 L2A tiles acquisition and storage f...
# 5   Sentinel-2 L1C tiles acquisition and storage f...
# 6   Sentinel-1 Level-2 consists of geolocated geop...
# 7   Sentinel-1 Level-1 products are the baseline p...
# 8   Level 3 snow products offers annual syntheses ...
# 9   At the end of life of each satellite, CNES iss...
# 10  The level 2A products correct the data for atm...
# 11  Main characteristics of the OSO Land Cover pro...
# 12  At the end of life of each satellite, CNES iss...
# 13  The Theia snow product indicates the snow pres...
# 14  Sea surface topography measurements to at leas...
# 15  At the end of life of each satellite, CNES iss...
# 16  At the end of life of each satellite, CNES iss...
# 17  Main characteristics of the OSO Land Cover pro...
#
#                                            collection
# 0     <Collection id=MUSCATE_Snow_SENTINEL2_L2B-SNOW>
# 1     <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L2A>
# 2     <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L3A>
# 3   <Collection id=MUSCATE_WaterQual_SENTINEL2_L2B...
# 4                         <Collection id=PEPS_S2_L2A>
# 5                         <Collection id=PEPS_S2_L1C>
# 6                          <Collection id=PEPS_S1_L2>
# 7                          <Collection id=PEPS_S1_L1>
# 8      <Collection id=MUSCATE_Snow_MULTISAT_L3B-SNOW>
# 9                     <Collection id=TAKE5_SPOT4_L1C>
# 10       <Collection id=MUSCATE_LANDSAT_LANDSAT8_L2A>
# 11         <Collection id=MUSCATE_OSO_RASTER_L3B-OSO>
# 12                    <Collection id=TAKE5_SPOT4_L2A>
# 13     <Collection id=MUSCATE_Snow_LANDSAT8_L2B-SNOW>
# 14                         <Collection id=PEPS_S3_L1>
# 15                    <Collection id=TAKE5_SPOT5_L1C>
# 16                    <Collection id=TAKE5_SPOT5_L2A>
# 17         <Collection id=MUSCATE_OSO_VECTOR_L3B-OSO>

# %% [markdown]
# The dataframe let's see you quickly see what you found, with only a few columns (here *description* and *title*), but if you are more comfortable working with raw objects, it's also possible.
#
# Let's see how many elements are in these collections.

# %%
for collection in collections:
    print(
        f"collection {collection.title} has {collection.summaries.other.get('total_items')} elements"
    )
# Out:
# collection MUSCATE Snow SENTINEL2 L2B has 91508 elements
# collection MUSCATE SENTINEL2 L2A has 1019637 elements
# collection MUSCATE SENTINEL2 L3A has 56011 elements
# collection MUSCATE WaterQual SENTINEL2 L2B has 138 elements
# collection PEPS Sentinel-2 L2A tiles has 0 elements
# collection PEPS Sentinel-2 L1C tiles has 34163668 elements
# collection PEPS Sentinel-1 Level2 has 1317955 elements
# collection PEPS Sentinel-1 Level1 has 5759206 elements
# collection MUSCATE L3B Snow has 667 elements
# collection TAKE5 SPOT4 LEVEL1C has 902 elements
# collection MUSCATE LANDSAT8 L2A has 27896 elements
# collection MUSCATE OSO RASTER has 8 elements
# collection TAKE5 SPOT4 LEVEL2A has 814 elements
# collection MUSCATE Snow LANDSAT8 L2B has 8708 elements
# collection GDH Sentinel-3 L1 STM Level-1 products has 46864 elements
# collection TAKE5 SPOT5 LEVEL1C has 3740 elements
# collection TAKE5 SPOT5 LEVEL2A has 2953 elements
# collection MUSCATE OSO VECTOR has 768 elements

# %% [markdown]
# We could want to add columns to our dataframe. To know which columns are available, use `collection.list_available_keys()` on a `Collection` object :

# %%
collections[0].list_available_keys()
# Out:
# {'assets.snow.description',
#  'assets.snow.href',
#  'assets.snow.roles',
#  'assets.snow.title',
#  'assets.snow.type',
#  'assets.wms_capabilities.description',
#  'assets.wms_capabilities.href',
#  'assets.wms_capabilities.roles',
#  'assets.wms_capabilities.title',
#  'assets.wms_capabilities.type',
#  'description',
#  'extent.spatial.bbox',
#  'extent.temporal.interval',
#  'id',
#  'keywords',
#  'license',
#  'links',
#  'providers',
#  'stac_extensions',
#  'stac_version',
#  'summaries.access_url',
#  'summaries.constellation',
#  'summaries.contact_email',
#  'summaries.contact_name',
#  'summaries.dataset',
#  'summaries.format',
#  'summaries.geometry_type',
#  'summaries.gsd',
#  'summaries.instruments',
#  'summaries.item_type',
#  'summaries.latest',
#  'summaries.platform',
#  'summaries.processing:level',
#  'summaries.temporal_resolution',
#  'summaries.theme',
#  'summaries.total_items',
#  'summaries.variables',
#  'summaries.version',
#  'title',
#  'type'}

# %% [markdown]
# Let's add `summaries.total_items` to the dataframe :

# %%
from pygeodes.utils.formatting import format_collections

new_dataframe = format_collections(
    dataframe, columns_to_add={"summaries.total_items"}
)

# %%
new_dataframe
# Out:
#                                      title  \
# 0               MUSCATE Snow SENTINEL2 L2B
# 1                    MUSCATE SENTINEL2 L2A
# 2                    MUSCATE SENTINEL2 L3A
# 3          MUSCATE WaterQual SENTINEL2 L2B
# 4                PEPS Sentinel-2 L2A tiles
# 5                PEPS Sentinel-2 L1C tiles
# 6                   PEPS Sentinel-1 Level2
# 7                   PEPS Sentinel-1 Level1
# 8                         MUSCATE L3B Snow
# 9                      TAKE5 SPOT4 LEVEL1C
# 10                    MUSCATE LANDSAT8 L2A
# 11                      MUSCATE OSO RASTER
# 12                     TAKE5 SPOT4 LEVEL2A
# 13               MUSCATE Snow LANDSAT8 L2B
# 14  GDH Sentinel-3 L1 STM Level-1 products
# 15                     TAKE5 SPOT5 LEVEL1C
# 16                     TAKE5 SPOT5 LEVEL2A
# 17                      MUSCATE OSO VECTOR
#
#                                           description  \
# 0   Theia Snow product is generated from Sentinel-...
# 1   The level 2A products correct the data for atm...
# 2   The products of level 3A provide a monthly syn...
# 3   The processing chain outputs rasters of the co...
# 4   Sentinel-2 L2A tiles acquisition and storage f...
# 5   Sentinel-2 L1C tiles acquisition and storage f...
# 6   Sentinel-1 Level-2 consists of geolocated geop...
# 7   Sentinel-1 Level-1 products are the baseline p...
# 8   Level 3 snow products offers annual syntheses ...
# 9   At the end of life of each satellite, CNES iss...
# 10  The level 2A products correct the data for atm...
# 11  Main characteristics of the OSO Land Cover pro...
# 12  At the end of life of each satellite, CNES iss...
# 13  The Theia snow product indicates the snow pres...
# 14  Sea surface topography measurements to at leas...
# 15  At the end of life of each satellite, CNES iss...
# 16  At the end of life of each satellite, CNES iss...
# 17  Main characteristics of the OSO Land Cover pro...
#
#                                            collection  summaries.total_items
# 0     <Collection id=MUSCATE_Snow_SENTINEL2_L2B-SNOW>                  91508
# 1     <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L2A>                1019637
# 2     <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L3A>                  56011
# 3   <Collection id=MUSCATE_WaterQual_SENTINEL2_L2B...                    138
# 4                         <Collection id=PEPS_S2_L2A>                      0
# 5                         <Collection id=PEPS_S2_L1C>               34163668
# 6                          <Collection id=PEPS_S1_L2>                1317955
# 7                          <Collection id=PEPS_S1_L1>                5759206
# 8      <Collection id=MUSCATE_Snow_MULTISAT_L3B-SNOW>                    667
# 9                     <Collection id=TAKE5_SPOT4_L1C>                    902
# 10       <Collection id=MUSCATE_LANDSAT_LANDSAT8_L2A>                  27896
# 11         <Collection id=MUSCATE_OSO_RASTER_L3B-OSO>                      8
# 12                    <Collection id=TAKE5_SPOT4_L2A>                    814
# 13     <Collection id=MUSCATE_Snow_LANDSAT8_L2B-SNOW>                   8708
# 14                         <Collection id=PEPS_S3_L1>                  46864
# 15                    <Collection id=TAKE5_SPOT5_L1C>                   3740
# 16                    <Collection id=TAKE5_SPOT5_L2A>                   2953
# 17         <Collection id=MUSCATE_OSO_VECTOR_L3B-OSO>                    768

# %% [markdown]
# If you wish to produce a fresh new dataframe with your custom columns, use `format_collections` on a list of collections :

# %%
new_dataframe = format_collections(
    collections,
    columns_to_add={"summaries.constellation", "summaries.instruments"},
)

# %%
new_dataframe
# Out:
#                                      title summaries.instruments  \
# 0               MUSCATE Snow SENTINEL2 L2B                 [OLI]
# 1                    MUSCATE SENTINEL2 L2A                 [MSI]
# 2                    MUSCATE SENTINEL2 L3A                 [MSI]
# 3          MUSCATE WaterQual SENTINEL2 L2B                    []
# 4                PEPS Sentinel-2 L2A tiles                 [MSI]
# 5                PEPS Sentinel-2 L1C tiles                 [MSI]
# 6                   PEPS Sentinel-1 Level2               [SAR-C]
# 7                   PEPS Sentinel-1 Level1               [SAR-C]
# 8                         MUSCATE L3B Snow            [OLI, MSI]
# 9                      TAKE5 SPOT4 LEVEL1C          [HRV, HRVIR]
# 10                    MUSCATE LANDSAT8 L2A                 [OLI]
# 11                      MUSCATE OSO RASTER                  None
# 12                     TAKE5 SPOT4 LEVEL2A          [HRV, HRVIR]
# 13               MUSCATE Snow LANDSAT8 L2B                 [OLI]
# 14  GDH Sentinel-3 L1 STM Level-1 products                [SRAL]
# 15                     TAKE5 SPOT5 LEVEL1C          [HRG1, HRG2]
# 16                     TAKE5 SPOT5 LEVEL2A          [HRG1, HRG2]
# 17                      MUSCATE OSO VECTOR                  None
#
#                                           description  \
# 0   Theia Snow product is generated from Sentinel-...
# 1   The level 2A products correct the data for atm...
# 2   The products of level 3A provide a monthly syn...
# 3   The processing chain outputs rasters of the co...
# 4   Sentinel-2 L2A tiles acquisition and storage f...
# 5   Sentinel-2 L1C tiles acquisition and storage f...
# 6   Sentinel-1 Level-2 consists of geolocated geop...
# 7   Sentinel-1 Level-1 products are the baseline p...
# 8   Level 3 snow products offers annual syntheses ...
# 9   At the end of life of each satellite, CNES iss...
# 10  The level 2A products correct the data for atm...
# 11  Main characteristics of the OSO Land Cover pro...
# 12  At the end of life of each satellite, CNES iss...
# 13  The Theia snow product indicates the snow pres...
# 14  Sea surface topography measurements to at leas...
# 15  At the end of life of each satellite, CNES iss...
# 16  At the end of life of each satellite, CNES iss...
# 17  Main characteristics of the OSO Land Cover pro...
#
#     summaries.constellation                                         collection
# 0              [sentinel-2]    <Collection id=MUSCATE_Snow_SENTINEL2_L2B-SNOW>
# 1              [sentinel-2]    <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L2A>
# 2              [sentinel-2]    <Collection id=MUSCATE_SENTINEL2_SENTINEL2_L3A>
# 3              [sentinel-2]  <Collection id=MUSCATE_WaterQual_SENTINEL2_L2B...
# 4              [sentinel-2]                        <Collection id=PEPS_S2_L2A>
# 5              [sentinel-2]                        <Collection id=PEPS_S2_L1C>
# 6              [sentinel-1]                         <Collection id=PEPS_S1_L2>
# 7              [sentinel-1]                         <Collection id=PEPS_S1_L1>
# 8   [sentinel-2, landsat-8]     <Collection id=MUSCATE_Snow_MULTISAT_L3B-SNOW>
# 9                  [spot-4]                    <Collection id=TAKE5_SPOT4_L1C>
# 10              [landsat-8]       <Collection id=MUSCATE_LANDSAT_LANDSAT8_L2A>
# 11             [sentinel-2]         <Collection id=MUSCATE_OSO_RASTER_L3B-OSO>
# 12                 [spot-4]                    <Collection id=TAKE5_SPOT4_L2A>
# 13              [landsat-8]     <Collection id=MUSCATE_Snow_LANDSAT8_L2B-SNOW>
# 14             [sentinel-3]                         <Collection id=PEPS_S3_L1>
# 15                 [spot-5]                    <Collection id=TAKE5_SPOT5_L1C>
# 16                 [spot-5]                    <Collection id=TAKE5_SPOT5_L2A>
# 17             [sentinel-2]         <Collection id=MUSCATE_OSO_VECTOR_L3B-OSO>

# %% [markdown]
# **Note** : `title` and `description` columns are always here by default.

# %% [markdown]
# ## Searching for items
#
# As for collections, we can search for items.
# To know which arguments to put in your query, please use :

# %%
from pygeodes.utils.query import get_requestable_args

print(get_requestable_args())
# Out:
# {'version': 'v8.0', 'attributes': ['dataset (STRING)', 'datetime (DATE_ISO8601)', 'links (STRING)', 'product_validity (BOOLEAN)', 'sci:doi (STRING_ARRAY)', 'no_geometry (BOOLEAN)', 'start_datetime (DATE_ISO8601)', 'end_datetime (DATE_ISO8601)', 'processing:datetime (DATE_ISO8601)', 'processing:lineage (STRING)', 'processing_context (STRING)', 'processing_correction (STRING)', 'processing:version (STRING)', 'bbox (STRING)', 'nb_cols (STRING)', 'nb_rows (STRING)', 'instrument (STRING)', 'platform (STRING)', 'sar:instrument_mode (STRING)', 'processing:level (STRING)', 'sar:polarizations (STRING)', 'sat:orbit_cycle (INTEGER)', 'mission_take_id (INTEGER)', 's2:datatake_id (STRING)', 'sat:relative_orbit (INTEGER)', 'sat:absolute_orbit (LONG)', 'sat:orbit_state (STRING)', 'product:type (STRING)', 'parameter (STRING)', 'pparameter (STRING)', 'product (STRING)', 'temporal_resolution (STRING)', 'classification (STRING)', 'swath (STRING)', 'bands (STRING)', 'grid:code (STRING)', 'eo:cloud_cover (DOUBLE)', 'water_cover (DOUBLE)', 'saturated_defective_pixel (DOUBLE)', 'nodata_pixel (DOUBLE)', 'nb_col_interpolation_error (DOUBLE)', 'ground_useful_pixel (DOUBLE)', 'min_useful_pixel (DOUBLE)', 'sensor_angle (DOUBLE)', 'sensor_pitch (DOUBLE)', 'sensor_roll (DOUBLE)', 'continent_code (STRING_ARRAY)', 'area (DOUBLE)', 'sar:beam_ids (STRING)', 'subTile (STRING)', 'keywords (STRING_ARRAY)', 'political (JSON)']}

# %% [markdown]
# We see we can use `sat:absolute_orbit`. Let's search for example those whose orbit direction is 30972:

# %%
query = {"sat:absolute_orbit": {"eq": 30972}}
items, dataframe = geodes.search_items(query=query, collections=['PEPS_S2_L1C'])
# Out:
# /work/scratch/data/fournih/test_env/lib/python3.11/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Found 760 items matching your query, returning 80 as get_all parameter is set to False
# 80 item(s) found for query : {'sat:absolute_orbit': {'eq': 30972}}

# %% [markdown]
# Again, we come out with an `items` object, and a `dataframe` object.

# %%
items[:10]  # printing everything is useless
# Out:
# [Item (URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-8925-415a7133a447:V1),
#  Item (URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-b44d-7e7fa7a74e9b:V1),
#  Item (URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-a560-b652e53906a4:V1),
#  Item (URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-8cd6-e215836fc505:V1),
#  Item (URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-b858-251fdb4aae7c:V1),
#  Item (URN:FEATURE:DATA:gdh:a6d9b9e0-250e-3cad-a77d-5a48608ce653:V1),
#  Item (URN:FEATURE:DATA:gdh:72989caf-a884-3018-a7ff-c464c835b21b:V1),
#  Item (URN:FEATURE:DATA:gdh:a449437f-8a51-3a1a-82e8-ea35b046b792:V1),
#  Item (URN:FEATURE:DATA:gdh:0967199f-0eb1-3189-a19a-fe443e4ad1c9:V1),
#  Item (URN:FEATURE:DATA:gdh:8550a63f-c516-3411-a5de-10fe155c94b5:V1)]

# %%
dataframe
# Out:
#      collection                                                 id  \
# 0   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-8925-4...
# 1   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-b44d-7...
# 2   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-a560-b...
# 3   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-8cd6-e...
# 4   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-b858-2...
# ..          ...                                                ...
# 75  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:5b627fa7-0cb9-3f4b-859f-b...
# 76  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:ac4f8ba9-73c6-3884-ba9f-c...
# 77  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:ebba0242-e75e-339d-8453-6...
# 78  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:932be784-66d0-3c77-8de3-1...
# 79  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:f1f066e9-9c4c-389b-9a58-b...
#
#     sat:absolute_orbit                                               item  \
# 0                30972  Item (URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-...
# 1                30972  Item (URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-...
# 2                30972  Item (URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-...
# 3                30972  Item (URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-...
# 4                30972  Item (URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-...
# ..                 ...                                                ...
# 75               30972  Item (URN:FEATURE:DATA:gdh:5b627fa7-0cb9-3f4b-...
# 76               30972  Item (URN:FEATURE:DATA:gdh:ac4f8ba9-73c6-3884-...
# 77               30972  Item (URN:FEATURE:DATA:gdh:ebba0242-e75e-339d-...
# 78               30972  Item (URN:FEATURE:DATA:gdh:932be784-66d0-3c77-...
# 79               30972  Item (URN:FEATURE:DATA:gdh:f1f066e9-9c4c-389b-...
#
#                                              geometry
# 0   POLYGON ((-169.24672 55.84483, -169.22768 56.2...
# 1   POLYGON ((164.21322 9.86133, 165.08902 9.8624,...
# 2   POLYGON ((-101.70029 80.94526, -101.70059 80.9...
# 3   POLYGON ((-178.52808 54.0505, -178.48457 54.05...
# 4   POLYGON ((-166.97714 63.02793, -164.80704 63.0...
# ..                                                ...
# 75  POLYGON ((158.99981 -19.98481, 160.0493 -19.98...
# 76  POLYGON ((123.406 -77.56412, 123.37673 -76.580...
# 77  POLYGON ((159.09139 -16.36923, 159.09095 -15.3...
# 78  POLYGON ((122.99922 -76.66867, 127.25737 -76.6...
# 79  POLYGON ((134.99931 -74.87589, 138.76418 -74.8...
#
# [80 rows x 5 columns]

# %% [markdown]
# Let's have a look around our items.
#
# A thing we could want to do is filter them by cloud cover, let's say between 39 and 40. But this column doesn't appear in the dataframe. To know which columns are available, use `item.list_available_keys()` on an `Item` object.

# %%
items[0].list_available_keys()
# Out:
# {'area',
#  'continent_code',
#  'dataset',
#  'datetime',
#  'end_datetime',
#  'endpoint_description',
#  'endpoint_url',
#  'eo:cloud_cover',
#  'grid:code',
#  'id',
#  'identifier',
#  'instrument',
#  'keywords',
#  'latest',
#  'physical',
#  'platform',
#  'political.continents',
#  'processing:level',
#  'processing:version',
#  'product:timeliness',
#  'product:type',
#  'proj:bbox',
#  'references',
#  's2:datatake_id',
#  'sar:instrument_mode',
#  'sat:absolute_orbit',
#  'sat:orbit_state',
#  'sat:relative_orbit',
#  'sci:doi',
#  'start_datetime',
#  'version'}

# %% [markdown]
# We see we can use `eo:cloud_cover`. We can add it using `format_items`.

# %%
from pygeodes.utils.formatting import format_items

new_dataframe = format_items(
    dataframe, columns_to_add={"eo:cloud_cover"}
)

# %%
new_dataframe
# Out:
#      collection                                                 id  \
# 0   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-8925-4...
# 1   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-b44d-7...
# 2   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-a560-b...
# 3   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-8cd6-e...
# 4   PEPS_S2_L1C  URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-b858-2...
# ..          ...                                                ...
# 75  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:5b627fa7-0cb9-3f4b-859f-b...
# 76  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:ac4f8ba9-73c6-3884-ba9f-c...
# 77  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:ebba0242-e75e-339d-8453-6...
# 78  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:932be784-66d0-3c77-8de3-1...
# 79  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:f1f066e9-9c4c-389b-9a58-b...
#
#     sat:absolute_orbit                                               item  \
# 0                30972  Item (URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-...
# 1                30972  Item (URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-...
# 2                30972  Item (URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-...
# 3                30972  Item (URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-...
# 4                30972  Item (URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-...
# ..                 ...                                                ...
# 75               30972  Item (URN:FEATURE:DATA:gdh:5b627fa7-0cb9-3f4b-...
# 76               30972  Item (URN:FEATURE:DATA:gdh:ac4f8ba9-73c6-3884-...
# 77               30972  Item (URN:FEATURE:DATA:gdh:ebba0242-e75e-339d-...
# 78               30972  Item (URN:FEATURE:DATA:gdh:932be784-66d0-3c77-...
# 79               30972  Item (URN:FEATURE:DATA:gdh:f1f066e9-9c4c-389b-...
#
#                                              geometry  eo:cloud_cover
# 0   POLYGON ((-169.24672 55.84483, -169.22768 56.2...      100.000000
# 1   POLYGON ((164.21322 9.86133, 165.08902 9.8624,...       53.467120
# 2   POLYGON ((-101.70029 80.94526, -101.70059 80.9...       10.542851
# 3   POLYGON ((-178.52808 54.0505, -178.48457 54.05...      100.000000
# 4   POLYGON ((-166.97714 63.02793, -164.80704 63.0...       99.999552
# ..                                                ...             ...
# 75  POLYGON ((158.99981 -19.98481, 160.0493 -19.98...       99.505091
# 76  POLYGON ((123.406 -77.56412, 123.37673 -76.580...       45.806925
# 77  POLYGON ((159.09139 -16.36923, 159.09095 -15.3...       59.269851
# 78  POLYGON ((122.99922 -76.66867, 127.25737 -76.6...       46.877837
# 79  POLYGON ((134.99931 -74.87589, 138.76418 -74.8...       18.401654
#
# [80 rows x 6 columns]

# %% [markdown]
# We've got our new dataframe. Let's filter :

# %%
filtered = new_dataframe[
    (new_dataframe["eo:cloud_cover"] <= 40)
    & (new_dataframe["eo:cloud_cover"] >= 39)
]

# %%
filtered
# Out:
#      collection                                                 id  \
# 73  PEPS_S2_L1C  URN:FEATURE:DATA:gdh:e4c321cd-3e90-3a97-a357-5...
#
#     sat:absolute_orbit                                               item  \
# 73               30972  Item (URN:FEATURE:DATA:gdh:e4c321cd-3e90-3a97-...
#
#                                              geometry  eo:cloud_cover
# 73  POLYGON ((170.99981 -15.46502, 171.41679 -15.4...       39.599036

# %% [markdown]
# Let's plot these items :

# %%
m = filtered.explore()

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5219eb18091d2dd6407f0454182951e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5219eb18091d2dd6407f0454182951e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5219eb18091d2dd6407f0454182951e2 = L.map(
#                 &quot;map_5219eb18091d2dd6407f0454182951e2&quot;,
#                 {
#                     center: [-15.2842214554725, 171.23511994782],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5219eb18091d2dd6407f0454182951e2);
#
#
#
#
#
#             var tile_layer_9dd5c1fadc95555096b6a8a5cf6612d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9dd5c1fadc95555096b6a8a5cf6612d9.addTo(map_5219eb18091d2dd6407f0454182951e2);
#
#
#             map_5219eb18091d2dd6407f0454182951e2.fitBounds(
#                 [[-15.465017044255, 170.99981355738], [-15.10342586669, 171.47042633826]],
#                 {}
#             );
#
#
#         function geo_json_d4e75828c5744f5ba24cab255517d6bb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d4e75828c5744f5ba24cab255517d6bb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d4e75828c5744f5ba24cab255517d6bb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d4e75828c5744f5ba24cab255517d6bb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d4e75828c5744f5ba24cab255517d6bb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d4e75828c5744f5ba24cab255517d6bb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d4e75828c5744f5ba24cab255517d6bb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d4e75828c5744f5ba24cab255517d6bb = L.geoJson(null, {
#                 onEachFeature: geo_json_d4e75828c5744f5ba24cab255517d6bb_onEachFeature,
#
#                 style: geo_json_d4e75828c5744f5ba24cab255517d6bb_styler,
#                 pointToLayer: geo_json_d4e75828c5744f5ba24cab255517d6bb_pointToLayer,
#         });
#
#         function geo_json_d4e75828c5744f5ba24cab255517d6bb_add (data) {
#             geo_json_d4e75828c5744f5ba24cab255517d6bb
#                 .addData(data);
#         }
#             geo_json_d4e75828c5744f5ba24cab255517d6bb_add({&quot;bbox&quot;: [170.99981355738, -15.465017044255, 171.47042633826, -15.10342586669], &quot;features&quot;: [{&quot;bbox&quot;: [170.99981355738, -15.465017044255, 171.47042633826, -15.10342586669], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[170.99981355738, -15.465017044255], [171.41679431512, -15.464054263786], [171.43759973074, -15.371267284933], [171.47042633826, -15.224730627274], [171.30004637747, -15.179091499567], [171.23970085188, -15.163199243925], [171.23975867859, -15.162942429127], [171.23028867598, -15.16040573023], [171.23024022454, -15.160620866755], [171.2299250137, -15.160543667325], [171.22986260203, -15.160820838439], [171.01827404118, -15.108906043118], [171.01845174025, -15.108120644018], [171.01828851545, -15.108080279522],

# %% [markdown]
# If you want to have all available columns in your dataframe, just do :

# %%
full_dataframe = format_items(
    items, columns_to_add=items[0].list_available_keys()
)

# %%
full_dataframe
# Out:
#         dataset                                         identifier  \
# 0   PEPS_S2_L1C  S2B_MSIL1C_20230209T223659_N0509_R058_T02VNH_2...
# 1   PEPS_S2_L1C  S2A_MSIL1C_20210527T233301_N0500_R087_T58PDS_2...
# 2   PEPS_S2_L1C  S2A_MSIL1C_20210527T231121_N0500_R087_T13XEL_2...
# 3   PEPS_S2_L1C  S2A_MSIL1C_20210527T231551_N0500_R087_T01UDA_2...
# 4   PEPS_S2_L1C  S2B_MSIL1C_20230209T223659_N0509_R058_T03VVL_2...
# ..          ...                                                ...
# 75  PEPS_S2_L1C  S2A_MSIL1C_20210527T233821_N0500_R087_T57KWU_2...
# 76  PEPS_S2_L1C  S2B_MSIL1C_20230209T231349_N0509_R058_T51CVQ_2...
# 77  PEPS_S2_L1C  S2A_MSIL1C_20210527T233821_N0500_R087_T57LVC_2...
# 78  PEPS_S2_L1C  S2B_MSIL1C_20230209T231349_N0509_R058_T51CWR_2...
# 79  PEPS_S2_L1C  S2B_MSIL1C_20230209T231349_N0509_R058_T53CNT_2...
#
#      collection                                         references  \
# 0   PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 1   PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 2   PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 3   PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 4   PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# ..          ...                                                ...
# 75  PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 76  PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 77  PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 78  PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
# 79  PEPS_S2_L1C  [{'license': 'Free of Charge', 'author': 'Natu...
#
#    continent_code  latest sci:doi product:timeliness         area  \
# 0              []    True      []            Nominal    980.05545
# 1              []    True      []            Nominal  10593.17538
# 2              []    True      []            Nominal      0.70304
# 3              []    True      []            Nominal    121.77404
# 4              []    True      []            Nominal  11984.99960
# ..            ...     ...     ...                ...          ...
# 75             []    True      []            Nominal  12100.69302
# 76           [AN]    True      []            Nominal   6682.91998
# 77             []    True      []            Nominal   6428.01994
# 78           [AN]    True      []            Nominal  11939.43830
# 79           [AN]    True      []            Nominal  11947.81665
#
#                                              keywords  ...  \
# 0                  [location:northern, season:winter]  ...
# 1   [location:tropical, location:northern, season:...  ...
# 2                  [location:northern, season:spring]  ...
# 3                  [location:northern, season:spring]  ...
# 4                  [location:northern, season:winter]  ...
# ..                                                ...  ...
# 75  [location:tropical, location:southern, season:...  ...
# 76                 [location:southern, season:summer]  ...
# 77  [location:tropical, location:southern, season:...  ...
# 78                 [location:southern, season:summer]  ...
# 79                 [location:southern, season:summer]  ...
#
#                                                    id grid:code  \
# 0   URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-8925-4...    T02VNH
# 1   URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-b44d-7...    T58PDS
# 2   URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-a560-b...    T13XEL
# 3   URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-8cd6-e...    T01UDA
# 4   URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-b858-2...    T03VVL
# ..                                                ...       ...
# 75  URN:FEATURE:DATA:gdh:5b627fa7-0cb9-3f4b-859f-b...    T57KWU
# 76  URN:FEATURE:DATA:gdh:ac4f8ba9-73c6-3884-ba9f-c...    T51CVQ
# 77  URN:FEATURE:DATA:gdh:ebba0242-e75e-339d-8453-6...    T57LVC
# 78  URN:FEATURE:DATA:gdh:932be784-66d0-3c77-8de3-1...    T51CWR
# 79  URN:FEATURE:DATA:gdh:f1f066e9-9c4c-389b-9a58-b...    T53CNT
#
#                                             proj:bbox  \
# 0   -169.24672,55.844830526696,-169.55016,56.31292...
# 1   164.21322248026,9.8613283265692,165.0892981652...
# 2   -101.70029,80.94526458256,-101.703735,81.05074...
# 3   -178.52808,54.050496442234,-178.40512,54.18715...
# 4   -166.97714,63.027933225685,-164.80026,64.02701...
# ..                                                ...
# 75  158.9998088233,-19.984806533577,160.0429308562...
# 76  123.40600037096,-77.564122823385,120.991597763...
# 77  159.09139182667,-16.369226028494,158.547456486...
# 78  122.9992229898,-76.668671848558,126.9712829074...
# 79  134.99931327677,-74.875894734017,138.540447574...
#
#                         s2:datatake_id sat:absolute_orbit  \
# 0   GS2B_20230209T223659_030972_N05.09              30972
# 1   GS2A_20210527T233301_030972_N05.00              30972
# 2   GS2A_20210527T231121_030972_N05.00              30972
# 3   GS2A_20210527T231551_030972_N05.00              30972
# 4   GS2B_20230209T223659_030972_N05.09              30972
# ..                                 ...                ...
# 75  GS2A_20210527T233821_030972_N05.00              30972
# 76  GS2B_20230209T231349_030972_N05.09              30972
# 77  GS2A_20210527T233821_030972_N05.00              30972
# 78  GS2B_20230209T231349_030972_N05.09              30972
# 79  GS2B_20230209T231349_030972_N05.09              30972
#
#                 end_datetime version sat:relative_orbit  \
# 0   2023-02-09T22:36:59.024Z   00.00                 58
# 1   2021-05-27T23:33:01.024Z   00.00                 87
# 2   2021-05-27T23:11:21.024Z   00.00                 87
# 3   2021-05-27T23:15:51.024Z   00.00                 87
# 4   2023-02-09T22:36:59.024Z   00.00                 58
# ..                       ...     ...                ...
# 75  2021-05-27T23:38:21.024Z   00.00                 87
# 76  2023-02-09T23:13:49.024Z   00.00                 58
# 77  2021-05-27T23:38:21.024Z   00.00                 87
# 78  2023-02-09T23:13:49.024Z   00.00                 58
# 79  2023-02-09T23:13:49.024Z   00.00                 58
#
#                                                  item  \
# 0   Item (URN:FEATURE:DATA:gdh:d939b8a4-7f6b-38ba-...
# 1   Item (URN:FEATURE:DATA:gdh:8c836d61-26f9-341b-...
# 2   Item (URN:FEATURE:DATA:gdh:ea6f4fb7-716a-3d5c-...
# 3   Item (URN:FEATURE:DATA:gdh:8728c52b-c8cc-3237-...
# 4   Item (URN:FEATURE:DATA:gdh:60d83cde-631a-3d28-...
# ..                                                ...
# 75  Item (URN:FEATURE:DATA:gdh:5b627fa7-0cb9-3f4b-...
# 76  Item (URN:FEATURE:DATA:gdh:ac4f8ba9-73c6-3884-...
# 77  Item (URN:FEATURE:DATA:gdh:ebba0242-e75e-339d-...
# 78  Item (URN:FEATURE:DATA:gdh:932be784-66d0-3c77-...
# 79  Item (URN:FEATURE:DATA:gdh:f1f066e9-9c4c-389b-...
#
#                                              geometry
# 0   POLYGON ((-169.24672 55.84483, -169.22768 56.2...
# 1   POLYGON ((164.21322 9.86133, 165.08902 9.8624,...
# 2   POLYGON ((-101.70029 80.94526, -101.70059 80.9...
# 3   POLYGON ((-178.52808 54.0505, -178.48457 54.05...
# 4   POLYGON ((-166.97714 63.02793, -164.80704 63.0...
# ..                                                ...
# 75  POLYGON ((158.99981 -19.98481, 160.0493 -19.98...
# 76  POLYGON ((123.406 -77.56412, 123.37673 -76.580...
# 77  POLYGON ((159.09139 -16.36923, 159.09095 -15.3...
# 78  POLYGON ((122.99922 -76.66867, 127.25737 -76.6...
# 79  POLYGON ((134.99931 -74.87589, 138.76418 -74.8...
#
# [80 rows x 34 columns]

# %% [markdown]
# ## Providing an api key
# The next parts involve requests that require an api-key. You can register one using the following method. We will also set a default download directory, for later. We use a file `config.json` formed as follows :
#
# ```json
# {"api_key" : "MyApiKey","download_dir" : "/tmp"}
# ```

# %%
from pygeodes import Config

conf = Config.from_file("config.json")
geodes.set_conf(conf)

# %% [markdown]
# Other ways to configure pygeodes are described in [configuration](configuration.rst).

# %% [markdown]
# ## Quicklook
# Now we can have a look at our items.

# %%
for item in filtered["item"]:
    print(f"Quicklook of {item}")
    item.show_quicklook()
# Out:
# Quicklook of Item (URN:FEATURE:DATA:gdh:e4c321cd-3e90-3a97-a357-5d64ca3e8e49:V1)
# /work/scratch/data/fournih/test_env/lib/python3.11/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %% [markdown]
# ## Downloading items

# %% [markdown]
# Now we could want to download these items for further use :

# %%
for item in filtered["item"]:
    item.download_archive()

# %% [markdown]
# As we provided `/tmp` as default download dir, the downloads are stored in this folder.
