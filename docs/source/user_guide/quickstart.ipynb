# %% [markdown]
# # Quickstart
# Now that you installation went ok, let's start with a small example.
# Let's create our first `Geodes` object.

# %%
from pygeodes import Geodes

geodes = Geodes()

# %% [markdown]
# ## Searching for collections
# Then we can start by searching for existing collections, for example with search term *sentinel* :

# %%
collections, dataframe = geodes.search_collections("sentinel")
# Out:
# /work/scratch/data/robertm/dev/env_tmp/pygeodes_cible/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexing: 100%|██████████| 66/66 [00:00<00:00, 2867.81it/s]

# %% [markdown]
# Let's see what we found. As a result, we get a `collections` object, which is a list of `Collection` objects.

# %%
collections
# Out:
# [<Collection id=THEIA_S1TILING_SENTINEL1_L1>,
#  <Collection id=THEIA_BIOPHY_SENTINEL2_L2B>,
#  <Collection id=THEIA_WATERQUAL_SENTINEL2_L2B>,
#  <Collection id=THEIA_REFLECTANCE_SENTINEL2_L3A>,
#  <Collection id=THEIA_REFLECTANCE_SENTINEL2_L2A>,
#  <Collection id=PEPS_S2_L1C>,
#  <Collection id=PEPS_S1_L2>,
#  <Collection id=PEPS_S1_L1>,
#  <Collection id=THEIA_SPOT4_TAKE5_L1C>,
#  <Collection id=THEIA_REFLECTANCE_LANDSAT8_L2A>,
#  <Collection id=THEIA_OSO_RASTER_L3B>,
#  <Collection id=THEIA_REFLECTANCE_SPOT4_TAKE5_L2A>,
#  <Collection id=PEPS_S3_L1>,
#  <Collection id=THEIA_SPOT5_TAKE5_L1C>,
#  <Collection id=THEIA_REFLECTANCE_SPOT5_TAKE5_L2A>,
#  <Collection id=THEIA_OSO_VECTOR_L3B>]

# %% [markdown]
# and a `dataframe` object, which is a `geopandas.GeoDataFrame`.

# %%
dataframe
# Out:
#                                      title  \
# 0               THEIA S1TILING SENTINEL L1
# 1               THEIA SENTINEL2 BIOPHY L2B
# 2            THEIA WaterQual SENTINEL2 L2B
# 3                      THEIA SENTINEL2 L3A
# 4                      THEIA SENTINEL2 L2A
# 5                PEPS Sentinel-2 L1C tiles
# 6                   PEPS Sentinel-1 Level2
# 7                   PEPS Sentinel-1 Level1
# 8                      TAKE5 SPOT4 LEVEL1C
# 9                       THEIA LANDSAT8 L2A
# 10                        THEIA OSO RASTER
# 11                     TAKE5 SPOT4 LEVEL2A
# 12  GDH Sentinel-3 L1 STM Level-1 products
# 13                     TAKE5 SPOT5 LEVEL1C
# 14                     TAKE5 SPOT5 LEVEL2A
# 15                        THEIA OSO VECTOR
#
#                                           description  \
# 0   S1TILING L1 products are based on Sentinel-1 L...
# 1   Biophysical variables characteristic of vegeta...
# 2   The processing chain outputs rasters of the co...
# 3   The products of level 3A provide a monthly syn...
# 4   The level 2A products correct the data for atm...
# 5   Sentinel-2 L1C tiles acquisition and storage f...
# 6   Sentinel-1 Level-2 consists of geolocated geop...
# 7   Sentinel-1 Level-1 products are the baseline p...
# 8   At the end of life of each satellite, CNES iss...
# 9   The level 2A products correct the data for atm...
# 10  Main characteristics of the OSO Land Cover pro...
# 11  At the end of life of each satellite, CNES iss...
# 12  Sea surface topography measurements to at leas...
# 13  At the end of life of each satellite, CNES iss...
# 14  At the end of life of each satellite, CNES iss...
# 15  Main characteristics of the OSO Land Cover pro...
#
#                                            collection
# 0         <Collection id=THEIA_S1TILING_SENTINEL1_L1>
# 1          <Collection id=THEIA_BIOPHY_SENTINEL2_L2B>
# 2       <Collection id=THEIA_WATERQUAL_SENTINEL2_L2B>
# 3     <Collection id=THEIA_REFLECTANCE_SENTINEL2_L3A>
# 4     <Collection id=THEIA_REFLECTANCE_SENTINEL2_L2A>
# 5                         <Collection id=PEPS_S2_L1C>
# 6                          <Collection id=PEPS_S1_L2>
# 7                          <Collection id=PEPS_S1_L1>
# 8               <Collection id=THEIA_SPOT4_TAKE5_L1C>
# 9      <Collection id=THEIA_REFLECTANCE_LANDSAT8_L2A>
# 10               <Collection id=THEIA_OSO_RASTER_L3B>
# 11  <Collection id=THEIA_REFLECTANCE_SPOT4_TAKE5_L2A>
# 12                         <Collection id=PEPS_S3_L1>
# 13              <Collection id=THEIA_SPOT5_TAKE5_L1C>
# 14  <Collection id=THEIA_REFLECTANCE_SPOT5_TAKE5_L2A>
# 15               <Collection id=THEIA_OSO_VECTOR_L3B>

# %% [markdown]
# The dataframe let's see you quickly see what you found, with only a few columns (here *description* and *title*), but if you are more comfortable working with raw objects, it's also possible.
#
# Let's see how many elements are in these collections.

# %%
for collection in collections:
    print(
        f"collection {collection.title} has {collection.summaries.other.get('total_items')} elements"
    )
# Out:
# collection THEIA S1TILING SENTINEL L1 has 0 elements
# collection THEIA SENTINEL2 BIOPHY L2B has 0 elements
# collection THEIA WaterQual SENTINEL2 L2B has 138 elements
# collection THEIA SENTINEL2 L3A has 63568 elements
# collection THEIA SENTINEL2 L2A has 2177670 elements
# collection PEPS Sentinel-2 L1C tiles has 37010592 elements
# collection PEPS Sentinel-1 Level2 has 1534336 elements
# collection PEPS Sentinel-1 Level1 has 6441578 elements
# collection TAKE5 SPOT4 LEVEL1C has 902 elements
# collection THEIA LANDSAT8 L2A has 27896 elements
# collection THEIA OSO RASTER has 9 elements
# collection TAKE5 SPOT4 LEVEL2A has 814 elements
# collection GDH Sentinel-3 L1 STM Level-1 products has 64805 elements
# collection TAKE5 SPOT5 LEVEL1C has 3740 elements
# collection TAKE5 SPOT5 LEVEL2A has 2953 elements
# collection THEIA OSO VECTOR has 864 elements

# %% [markdown]
# We could want to add columns to our dataframe. To know which columns are available, use `collection.list_available_keys()` on a `Collection` object :

# %%
collections[0].list_available_keys()
# Out:
# {'assets.bs.description',
#  'assets.bs.href',
#  'assets.bs.roles',
#  'assets.bs.title',
#  'assets.bs.type',
#  'assets.wms_capabilities.description',
#  'assets.wms_capabilities.href',
#  'assets.wms_capabilities.roles',
#  'assets.wms_capabilities.title',
#  'assets.wms_capabilities.type',
#  'description',
#  'extent.spatial.bbox',
#  'extent.temporal.interval',
#  'id',
#  'keywords',
#  'license',
#  'links',
#  'providers',
#  'stac_extensions',
#  'stac_version',
#  'summaries.access_url',
#  'summaries.constellation',
#  'summaries.contact_email',
#  'summaries.contact_name',
#  'summaries.dataset',
#  'summaries.format',
#  'summaries.geometry_type',
#  'summaries.gsd',
#  'summaries.instruments',
#  'summaries.item_type',
#  'summaries.latest',
#  'summaries.missions',
#  'summaries.platform',
#  'summaries.processing:level',
#  'summaries.production_frequency',
#  'summaries.temporal_resolution',
#  'summaries.theme',
#  'summaries.total_items',
#  'summaries.variables',
#  'summaries.version',
#  'title',
#  'type'}

# %% [markdown]
# Let's add `summaries.total_items` to the dataframe :

# %%
from pygeodes.utils.formatting import format_collections

new_dataframe = format_collections(
    dataframe, columns_to_add={"summaries.total_items"}
)

# %%
new_dataframe
# Out:
#                                      title  \
# 0               THEIA S1TILING SENTINEL L1
# 1               THEIA SENTINEL2 BIOPHY L2B
# 2            THEIA WaterQual SENTINEL2 L2B
# 3                      THEIA SENTINEL2 L3A
# 4                      THEIA SENTINEL2 L2A
# 5                PEPS Sentinel-2 L1C tiles
# 6                   PEPS Sentinel-1 Level2
# 7                   PEPS Sentinel-1 Level1
# 8                      TAKE5 SPOT4 LEVEL1C
# 9                       THEIA LANDSAT8 L2A
# 10                        THEIA OSO RASTER
# 11                     TAKE5 SPOT4 LEVEL2A
# 12  GDH Sentinel-3 L1 STM Level-1 products
# 13                     TAKE5 SPOT5 LEVEL1C
# 14                     TAKE5 SPOT5 LEVEL2A
# 15                        THEIA OSO VECTOR
#
#                                           description  \
# 0   S1TILING L1 products are based on Sentinel-1 L...
# 1   Biophysical variables characteristic of vegeta...
# 2   The processing chain outputs rasters of the co...
# 3   The products of level 3A provide a monthly syn...
# 4   The level 2A products correct the data for atm...
# 5   Sentinel-2 L1C tiles acquisition and storage f...
# 6   Sentinel-1 Level-2 consists of geolocated geop...
# 7   Sentinel-1 Level-1 products are the baseline p...
# 8   At the end of life of each satellite, CNES iss...
# 9   The level 2A products correct the data for atm...
# 10  Main characteristics of the OSO Land Cover pro...
# 11  At the end of life of each satellite, CNES iss...
# 12  Sea surface topography measurements to at leas...
# 13  At the end of life of each satellite, CNES iss...
# 14  At the end of life of each satellite, CNES iss...
# 15  Main characteristics of the OSO Land Cover pro...
#
#                                            collection  summaries.total_items
# 0         <Collection id=THEIA_S1TILING_SENTINEL1_L1>                      0
# 1          <Collection id=THEIA_BIOPHY_SENTINEL2_L2B>                      0
# 2       <Collection id=THEIA_WATERQUAL_SENTINEL2_L2B>                    138
# 3     <Collection id=THEIA_REFLECTANCE_SENTINEL2_L3A>                  63568
# 4     <Collection id=THEIA_REFLECTANCE_SENTINEL2_L2A>                2177670
# 5                         <Collection id=PEPS_S2_L1C>               37010592
# 6                          <Collection id=PEPS_S1_L2>                1534336
# 7                          <Collection id=PEPS_S1_L1>                6441578
# 8               <Collection id=THEIA_SPOT4_TAKE5_L1C>                    902
# 9      <Collection id=THEIA_REFLECTANCE_LANDSAT8_L2A>                  27896
# 10               <Collection id=THEIA_OSO_RASTER_L3B>                      9
# 11  <Collection id=THEIA_REFLECTANCE_SPOT4_TAKE5_L2A>                    814
# 12                         <Collection id=PEPS_S3_L1>                  64805
# 13              <Collection id=THEIA_SPOT5_TAKE5_L1C>                   3740
# 14  <Collection id=THEIA_REFLECTANCE_SPOT5_TAKE5_L2A>                   2953
# 15               <Collection id=THEIA_OSO_VECTOR_L3B>                    864

# %% [markdown]
# If you wish to produce a fresh new dataframe with your custom columns, use `format_collections` on a list of collections :

# %%
new_dataframe = format_collections(
    collections,
    columns_to_add={"summaries.constellation", "summaries.instruments"},
)

# %%
new_dataframe
# Out:
#    summaries.constellation summaries.instruments  \
# 0             [sentinel-1]                 [SAR]
# 1             [sentinel-2]                 [MSI]
# 2             [sentinel-2]                    []
# 3             [sentinel-2]                 [MSI]
# 4             [sentinel-2]                 [MSI]
# 5             [sentinel-2]                 [MSI]
# 6             [sentinel-1]               [SAR-C]
# 7             [sentinel-1]               [SAR-C]
# 8                 [spot-4]          [HRV, HRVIR]
# 9              [landsat-8]                 [OLI]
# 10            [sentinel-2]                  None
# 11                [spot-4]          [HRV, HRVIR]
# 12            [sentinel-3]                [SRAL]
# 13                [spot-5]          [HRG1, HRG2]
# 14                [spot-5]          [HRG1, HRG2]
# 15            [sentinel-2]                  None
#
#                                      title  \
# 0               THEIA S1TILING SENTINEL L1
# 1               THEIA SENTINEL2 BIOPHY L2B
# 2            THEIA WaterQual SENTINEL2 L2B
# 3                      THEIA SENTINEL2 L3A
# 4                      THEIA SENTINEL2 L2A
# 5                PEPS Sentinel-2 L1C tiles
# 6                   PEPS Sentinel-1 Level2
# 7                   PEPS Sentinel-1 Level1
# 8                      TAKE5 SPOT4 LEVEL1C
# 9                       THEIA LANDSAT8 L2A
# 10                        THEIA OSO RASTER
# 11                     TAKE5 SPOT4 LEVEL2A
# 12  GDH Sentinel-3 L1 STM Level-1 products
# 13                     TAKE5 SPOT5 LEVEL1C
# 14                     TAKE5 SPOT5 LEVEL2A
# 15                        THEIA OSO VECTOR
#
#                                           description  \
# 0   S1TILING L1 products are based on Sentinel-1 L...
# 1   Biophysical variables characteristic of vegeta...
# 2   The processing chain outputs rasters of the co...
# 3   The products of level 3A provide a monthly syn...
# 4   The level 2A products correct the data for atm...
# 5   Sentinel-2 L1C tiles acquisition and storage f...
# 6   Sentinel-1 Level-2 consists of geolocated geop...
# 7   Sentinel-1 Level-1 products are the baseline p...
# 8   At the end of life of each satellite, CNES iss...
# 9   The level 2A products correct the data for atm...
# 10  Main characteristics of the OSO Land Cover pro...
# 11  At the end of life of each satellite, CNES iss...
# 12  Sea surface topography measurements to at leas...
# 13  At the end of life of each satellite, CNES iss...
# 14  At the end of life of each satellite, CNES iss...
# 15  Main characteristics of the OSO Land Cover pro...
#
#                                            collection
# 0         <Collection id=THEIA_S1TILING_SENTINEL1_L1>
# 1          <Collection id=THEIA_BIOPHY_SENTINEL2_L2B>
# 2       <Collection id=THEIA_WATERQUAL_SENTINEL2_L2B>
# 3     <Collection id=THEIA_REFLECTANCE_SENTINEL2_L3A>
# 4     <Collection id=THEIA_REFLECTANCE_SENTINEL2_L2A>
# 5                         <Collection id=PEPS_S2_L1C>
# 6                          <Collection id=PEPS_S1_L2>
# 7                          <Collection id=PEPS_S1_L1>
# 8               <Collection id=THEIA_SPOT4_TAKE5_L1C>
# 9      <Collection id=THEIA_REFLECTANCE_LANDSAT8_L2A>
# 10               <Collection id=THEIA_OSO_RASTER_L3B>
# 11  <Collection id=THEIA_REFLECTANCE_SPOT4_TAKE5_L2A>
# 12                         <Collection id=PEPS_S3_L1>
# 13              <Collection id=THEIA_SPOT5_TAKE5_L1C>
# 14  <Collection id=THEIA_REFLECTANCE_SPOT5_TAKE5_L2A>
# 15               <Collection id=THEIA_OSO_VECTOR_L3B>

# %% [markdown]
# **Note** : `title` and `description` columns are always here by default.

# %% [markdown]
# ## Searching for items
#
# As for collections, we can search for items.
# To know which arguments to put in your query, please use :

# %%
from pygeodes.utils.query import get_requestable_args

print(get_requestable_args())
# Out:
# {'version': 'v8.0', 'attributes': ['dataset (STRING)', 'datetime (DATE_ISO8601)', 'links (STRING)', 'product_validity (BOOLEAN)', 'sci:doi (STRING_ARRAY)', 'no_geometry (BOOLEAN)', 'start_datetime (DATE_ISO8601)', 'end_datetime (DATE_ISO8601)', 'processing:datetime (DATE_ISO8601)', 'processing:lineage (STRING)', 'processing_context (STRING)', 'processing_correction (STRING)', 'processing:version (STRING)', 'bbox (STRING)', 'nb_cols (STRING)', 'nb_rows (STRING)', 'instrument (STRING)', 'platform (STRING)', 'sar:instrument_mode (STRING)', 'processing:level (STRING)', 'sar:polarizations (STRING)', 'sat:orbit_cycle (INTEGER)', 'mission_take_id (INTEGER)', 's2:datatake_id (STRING)', 'sat:relative_orbit (INTEGER)', 'sat:absolute_orbit (LONG)', 'sat:orbit_state (STRING)', 'product:type (STRING)', 'parameter (STRING)', 'pparameter (STRING)', 'product (STRING)', 'temporal_resolution (STRING)', 'classification (STRING)', 'swath (STRING)', 'bands (STRING)', 'grid:code (STRING)', 'eo:cloud_cover (DOUBLE)', 'water_cover (DOUBLE)', 'saturated_defective_pixel (DOUBLE)', 'nodata_pixel (DOUBLE)', 'nb_col_interpolation_error (DOUBLE)', 'ground_useful_pixel (DOUBLE)', 'min_useful_pixel (DOUBLE)', 'sensor_angle (DOUBLE)', 'sensor_pitch (DOUBLE)', 'sensor_roll (DOUBLE)', 'continent_code (STRING_ARRAY)', 'area (DOUBLE)', 'sar:beam_ids (STRING)', 'subTile (STRING)', 'keywords (STRING_ARRAY)', 'political (JSON)']}

# %% [raw]
# We see we can use `sat:relative_orbit`. Let's search for example those whose orbit direction is 4:

# %%
query = {"sat:relative_orbit": {"eq": 4}}
sortBy = [{"direction":"desc","field":"start_datetime"}]
items, dataframe = geodes.search_items(query=query, sortBy=sortBy, collections=['PEPS_S2_L1C'])
# Out:
# /work/scratch/data/robertm/dev/env_tmp/pygeodes_cible/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Found 258470 items matching your query, returning 80 as get_all parameter is set to False
# 80 item(s) found for query : {'sat:relative_orbit': {'eq': 4}}

# %% [markdown]
# Again, we come out with an `items` object, and a `dataframe` object.

# %%
items[:10]  # printing everything is useless
# Out:
# [Item (URN:FEATURE:DATA:gdh:8f917459-f72f-341c-a713-ca7f0ff0f01e:V1),
#  Item (URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-8de6-506412807a08:V1),
#  Item (URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-8d83-7f7248720e16:V1),
#  Item (URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-a8e6-202b9a73afdd:V1),
#  Item (URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-8f9e-661d919563f0:V1),
#  Item (URN:FEATURE:DATA:gdh:11eebd44-01fd-3089-8d1c-2ce0a4d0b6fe:V1),
#  Item (URN:FEATURE:DATA:gdh:ec36c006-0b3a-36c3-9f46-69f2f3be8ab8:V1),
#  Item (URN:FEATURE:DATA:gdh:0d56d04e-1f05-3bae-9ada-1deef90a9ba0:V1),
#  Item (URN:FEATURE:DATA:gdh:3b46df15-8955-35b4-a3e4-a6ba178c1d4c:V1),
#  Item (URN:FEATURE:DATA:gdh:71c19643-9924-3684-810f-58c5432cdcf8:V1)]

# %%
dataframe
# Out:
#                                                    id  sat:relative_orbit  \
# 0   URN:FEATURE:DATA:gdh:8f917459-f72f-341c-a713-c...                   4
# 1   URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-8de6-5...                   4
# 2   URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-8d83-7...                   4
# 3   URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-a8e6-2...                   4
# 4   URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-8f9e-6...                   4
# ..                                                ...                 ...
# 75  URN:FEATURE:DATA:gdh:4c758d19-7362-3e27-812b-5...                   4
# 76  URN:FEATURE:DATA:gdh:59d3bc97-c0e2-308d-94ab-2...                   4
# 77  URN:FEATURE:DATA:gdh:8c9455d5-9faf-31bc-bafd-8...                   4
# 78  URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-8bd6-8...                   4
# 79  URN:FEATURE:DATA:gdh:0939f7e3-f40e-31c9-b6c3-8...                   4
#
#      collection                                               item  \
# 0   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:8f917459-f72f-341c-...
# 1   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-...
# 2   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-...
# 3   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-...
# 4   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-...
# ..          ...                                                ...
# 75  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:4c758d19-7362-3e27-...
# 76  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:59d3bc97-c0e2-308d-...
# 77  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:8c9455d5-9faf-31bc-...
# 78  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-...
# 79  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:0939f7e3-f40e-31c9-...
#
#                                              geometry
# 0   POLYGON ((96.19312 16.26222, 96.20672 15.27075...
# 1   POLYGON ((103.08352 45.94729, 103.83596 45.959...
# 2   POLYGON ((101.5455 38.79789, 101.59209 37.8101...
# 3   POLYGON ((101.24793 37.02528, 101.21947 36.036...
# 4   POLYGON ((107.79861 47.73874, 107.80285 47.819...
# ..                                                ...
# 75  POLYGON ((104.99971 51.04807, 104.99972 50.463...
# 76  POLYGON ((101.45454 40.5964, 101.50549 39.6090...
# 77  POLYGON ((114.81208 65.80592, 114.89231 64.821...
# 78  POLYGON ((101.43771 40.90608, 101.45918 40.508...
# 79  POLYGON ((111.06215 54.14751, 109.46869 54.138...
#
# [80 rows x 5 columns]

# %% [markdown]
# Let's have a look around our items.
#
# A thing we could want to do is filter them by cloud cover, let's say between 39 and 40. But this column doesn't appear in the dataframe. To know which columns are available, use `item.list_available_keys()` on an `Item` object.

# %%
items[0].list_available_keys()
# Out:
# {'area',
#  'continent_code',
#  'dataset',
#  'datetime',
#  'end_datetime',
#  'endpoint_description',
#  'endpoint_url',
#  'eo:cloud_cover',
#  'grid:code',
#  'id',
#  'identifier',
#  'instrument',
#  'keywords',
#  'latest',
#  'physical',
#  'platform',
#  'political.continents',
#  'processing:level',
#  'product:timeliness',
#  'product:type',
#  'proj:bbox',
#  'references',
#  's2:datatake_id',
#  'sar:instrument_mode',
#  'sat:absolute_orbit',
#  'sat:orbit_state',
#  'sat:relative_orbit',
#  'sci:doi',
#  'start_datetime'}

# %% [markdown]
# We see we can use `eo:cloud_cover`. We can add it using `format_items`.

# %%
from pygeodes.utils.formatting import format_items

new_dataframe = format_items(
    dataframe, columns_to_add={"eo:cloud_cover"}
)

# %%
new_dataframe
# Out:
#                                                    id  sat:relative_orbit  \
# 0   URN:FEATURE:DATA:gdh:8f917459-f72f-341c-a713-c...                   4
# 1   URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-8de6-5...                   4
# 2   URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-8d83-7...                   4
# 3   URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-a8e6-2...                   4
# 4   URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-8f9e-6...                   4
# ..                                                ...                 ...
# 75  URN:FEATURE:DATA:gdh:4c758d19-7362-3e27-812b-5...                   4
# 76  URN:FEATURE:DATA:gdh:59d3bc97-c0e2-308d-94ab-2...                   4
# 77  URN:FEATURE:DATA:gdh:8c9455d5-9faf-31bc-bafd-8...                   4
# 78  URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-8bd6-8...                   4
# 79  URN:FEATURE:DATA:gdh:0939f7e3-f40e-31c9-b6c3-8...                   4
#
#      collection                                               item  \
# 0   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:8f917459-f72f-341c-...
# 1   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-...
# 2   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-...
# 3   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-...
# 4   PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-...
# ..          ...                                                ...
# 75  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:4c758d19-7362-3e27-...
# 76  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:59d3bc97-c0e2-308d-...
# 77  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:8c9455d5-9faf-31bc-...
# 78  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-...
# 79  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:0939f7e3-f40e-31c9-...
#
#                                              geometry  eo:cloud_cover
# 0   POLYGON ((96.19312 16.26222, 96.20672 15.27075...       76.241363
# 1   POLYGON ((103.08352 45.94729, 103.83596 45.959...        0.256226
# 2   POLYGON ((101.5455 38.79789, 101.59209 37.8101...        0.000000
# 3   POLYGON ((101.24793 37.02528, 101.21947 36.036...        0.019051
# 4   POLYGON ((107.79861 47.73874, 107.80285 47.819...        0.009339
# ..                                                ...             ...
# 75  POLYGON ((104.99971 51.04807, 104.99972 50.463...       14.084793
# 76  POLYGON ((101.45454 40.5964, 101.50549 39.6090...        0.431813
# 77  POLYGON ((114.81208 65.80592, 114.89231 64.821...       99.982412
# 78  POLYGON ((101.43771 40.90608, 101.45918 40.508...       29.061980
# 79  POLYGON ((111.06215 54.14751, 109.46869 54.138...       76.702719
#
# [80 rows x 6 columns]

# %% [markdown]
# We've got our new dataframe. Let's filter :

# %%
filtered = new_dataframe[
    (new_dataframe["eo:cloud_cover"] <= 30)
    & (new_dataframe["eo:cloud_cover"] >= 29)
]

# %%
filtered
# Out:
#                                                    id  sat:relative_orbit  \
# 78  URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-8bd6-8...                   4
#
#      collection                                               item  \
# 78  PEPS_S2_L1C  Item (URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-...
#
#                                              geometry  eo:cloud_cover
# 78  POLYGON ((101.43771 40.90608, 101.45918 40.508...        29.06198

# %% [markdown]
# Let's plot these items :

# %%
##Folim is required for the command below. You can install in your Python environment by executing pip install "folium>=0.12" matplotlib mapclassify
m = filtered.explore()

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e318b29099bbf0dcd7024b307e7c9426 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e318b29099bbf0dcd7024b307e7c9426&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e318b29099bbf0dcd7024b307e7c9426 = L.map(
#                 &quot;map_e318b29099bbf0dcd7024b307e7c9426&quot;,
#                 {
#                     center: [41.018849163285, 102.095761059925],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e318b29099bbf0dcd7024b307e7c9426);
#
#
#
#
#
#             var tile_layer_fb7c103b0ef961453aa16a07d13dd791 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb7c103b0ef961453aa16a07d13dd791.addTo(map_e318b29099bbf0dcd7024b307e7c9426);
#
#
#             map_e318b29099bbf0dcd7024b307e7c9426.fitBounds(
#                 [[40.508462825852, 101.43770823825], [41.529235500718, 102.7538138816]],
#                 {}
#             );
#
#
#         function geo_json_b7057f80c4a1821d7beff9c8adc85271_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b7057f80c4a1821d7beff9c8adc85271_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b7057f80c4a1821d7beff9c8adc85271_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_b7057f80c4a1821d7beff9c8adc85271_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b7057f80c4a1821d7beff9c8adc85271_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b7057f80c4a1821d7beff9c8adc85271.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b7057f80c4a1821d7beff9c8adc85271_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b7057f80c4a1821d7beff9c8adc85271 = L.geoJson(null, {
#                 onEachFeature: geo_json_b7057f80c4a1821d7beff9c8adc85271_onEachFeature,
#
#                 style: geo_json_b7057f80c4a1821d7beff9c8adc85271_styler,
#                 pointToLayer: geo_json_b7057f80c4a1821d7beff9c8adc85271_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b7057f80c4a1821d7beff9c8adc85271_add (data) {
#             geo_json_b7057f80c4a1821d7beff9c8adc85271
#                 .addData(data);
#         }
#             geo_json_b7057f80c4a1821d7beff9c8adc85271_add({&quot;bbox&quot;: [101.43770823825, 40.508462825852, 102.7538138816, 41.529235500718], &quot;features&quot;: [{&quot;bbox&quot;: [101.43770823825, 40.508462825852, 102.7538138816, 41.529235500718], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[101.43770823825, 40.906084345864], [101.45917739747, 40.508462825852], [102.7538138816, 40.540909994828], [102.7199481155, 41.529235500718], [101.62197921802, 41.501170273019], [101.61781458701, 41.487773

# %% [markdown]
# If you want to have all available columns in your dataframe, just do :

# %%
full_dataframe = format_items(
    items, columns_to_add=items[0].list_available_keys()
)

# %%
full_dataframe
# Out:
#                                                    id proj:bbox  \
# 0   URN:FEATURE:DATA:gdh:8f917459-f72f-341c-a713-c...
# 1   URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-8de6-5...
# 2   URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-8d83-7...
# 3   URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-a8e6-2...
# 4   URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-8f9e-6...
# ..                                                ...       ...
# 75  URN:FEATURE:DATA:gdh:4c758d19-7362-3e27-812b-5...
# 76  URN:FEATURE:DATA:gdh:59d3bc97-c0e2-308d-94ab-2...
# 77  URN:FEATURE:DATA:gdh:8c9455d5-9faf-31bc-bafd-8...
# 78  URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-8bd6-8...
# 79  URN:FEATURE:DATA:gdh:0939f7e3-f40e-31c9-b6c3-8...
#
#            endpoint_description   collection sat:orbit_state  \
# 0   Link to product in datalake  PEPS_S2_L1C      Descending
# 1   Link to product in datalake  PEPS_S2_L1C      Descending
# 2   Link to product in datalake  PEPS_S2_L1C      Descending
# 3   Link to product in datalake  PEPS_S2_L1C      Descending
# 4   Link to product in datalake  PEPS_S2_L1C      Descending
# ..                          ...          ...             ...
# 75  Link to product in datalake  PEPS_S2_L1C      Descending
# 76  Link to product in datalake  PEPS_S2_L1C      Descending
# 77  Link to product in datalake  PEPS_S2_L1C      Descending
# 78  Link to product in datalake  PEPS_S2_L1C      Descending
# 79  Link to product in datalake  PEPS_S2_L1C      Descending
#
#    product:timeliness                               political.continents  \
# 0             Nominal                                                 []
# 1             Nominal  [{'id': 'continent:Asia:6255147', 'name': 'Asi...
# 2             Nominal  [{'id': 'continent:Asia:6255147', 'name': 'Asi...
# 3             Nominal  [{'id': 'continent:Asia:6255147', 'name': 'Asi...
# 4             Nominal  [{'id': 'continent:Asia:6255147', 'name': 'Asi...
# ..                ...                                                ...
# 75            Nominal  [{'id': 'continent:Europe:6255148', 'name': 'E...
# 76            Nominal  [{'id': 'continent:Asia:6255147', 'name': 'Asi...
# 77            Nominal  [{'id': 'continent:Europe:6255148', 'name': 'E...
# 78            Nominal  [{'id': 'continent:Asia:6255147', 'name': 'Asi...
# 79            Nominal  [{'id': 'continent:Europe:6255148', 'name': 'E...
#
#    product:type processing:level  \
# 0       S2MSI1C              L1C
# 1       S2MSI1C              L1C
# 2       S2MSI1C              L1C
# 3       S2MSI1C              L1C
# 4       S2MSI1C              L1C
# ..          ...              ...
# 75      S2MSI1C              L1C
# 76      S2MSI1C              L1C
# 77      S2MSI1C              L1C
# 78      S2MSI1C              L1C
# 79      S2MSI1C              L1C
#
#                                          endpoint_url  ...  \
# 0   https://s3.datalake.cnes.fr/sentinel2-l1c/47/P...  ...
# 1   https://s3.datalake.cnes.fr/sentinel2-l1c/48/T...  ...
# 2   https://s3.datalake.cnes.fr/sentinel2-l1c/48/S...  ...
# 3   https://s3.datalake.cnes.fr/sentinel2-l1c/47/S...  ...
# 4   https://s3.datalake.cnes.fr/sentinel2-l1c/48/T...  ...
# ..                                                ...  ...
# 75  https://s3.datalake.cnes.fr/sentinel2-l1c/48/U...  ...
# 76  https://s3.datalake.cnes.fr/sentinel2-l1c/48/T...  ...
# 77  https://s3.datalake.cnes.fr/sentinel2-l1c/50/W...  ...
# 78  https://s3.datalake.cnes.fr/sentinel2-l1c/48/T...  ...
# 79  https://s3.datalake.cnes.fr/sentinel2-l1c/49/U...  ...
#
#                                            references grid:code  \
# 0   [{'url': 'http://www.naturalearthdata.com/down...    T47PKT
# 1   [{'url': 'http://www.naturalearthdata.com/down...    T48TUS
# 2   [{'url': 'http://www.naturalearthdata.com/down...    T48STH
# 3   [{'url': 'http://www.naturalearthdata.com/down...    T47SQA
# 4   [{'url': 'http://www.naturalearthdata.com/down...    T48TXT
# ..                                                ...       ...
# 75  [{'url': 'http://www.naturalearthdata.com/down...    T48UWB
# 76  [{'url': 'http://www.naturalearthdata.com/down...    T48TTK
# 77  [{'url': 'http://www.naturalearthdata.com/down...    T50WMT
# 78  [{'url': 'http://www.naturalearthdata.com/down...    T48TTL
# 79  [{'url': 'http://www.naturalearthdata.com/down...    T49UDV
#
#                                            identifier  eo:cloud_cover  \
# 0   S2C_MSIL1C_20260215T035841_N0512_R004_T47PKT_2...       76.241363
# 1   S2C_MSIL1C_20260215T035841_N0512_R004_T48TUS_2...        0.256226
# 2   S2C_MSIL1C_20260215T035841_N0512_R004_T48STH_2...        0.000000
# 3   S2C_MSIL1C_20260215T035841_N0512_R004_T47SQA_2...        0.019051
# 4   S2C_MSIL1C_20260215T035841_N0512_R004_T48TXT_2...        0.009339
# ..                                                ...             ...
# 75  S2C_MSIL1C_20260215T035841_N0512_R004_T48UWB_2...       14.084793
# 76  S2C_MSIL1C_20260215T035841_N0512_R004_T48TTK_2...        0.431813
# 77  S2C_MSIL1C_20260215T035841_N0512_R004_T50WMT_2...       99.982412
# 78  S2C_MSIL1C_20260215T035841_N0512_R004_T48TTL_2...       29.061980
# 79  S2C_MSIL1C_20260215T035841_N0512_R004_T49UDV_2...       76.702719
#
#    sar:instrument_mode                                           keywords  \
# 0             INS-NOBS  [location:tropical, location:northern, season:...
# 1             INS-NOBS                 [location:northern, season:winter]
# 2             INS-NOBS                 [location:northern, season:winter]
# 3             INS-NOBS                 [location:northern, season:winter]
# 4             INS-NOBS                 [location:northern, season:winter]
# ..                 ...                                                ...
# 75            INS-NOBS                 [location:northern, season:winter]
# 76            INS-NOBS                 [location:northern, season:winter]
# 77            INS-NOBS                 [location:northern, season:winter]
# 78            INS-NOBS                 [location:northern, season:winter]
# 79            INS-NOBS                 [location:northern, season:winter]
#
#                 end_datetime            start_datetime  \
# 0   2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 1   2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 2   2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 3   2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 4   2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# ..                       ...                       ...
# 75  2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 76  2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 77  2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 78  2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
# 79  2026-02-15T03:58:41.025Z  2026-02-15T03:58:41.025Z
#
#                                                  item  \
# 0   Item (URN:FEATURE:DATA:gdh:8f917459-f72f-341c-...
# 1   Item (URN:FEATURE:DATA:gdh:c052606a-1e73-37c8-...
# 2   Item (URN:FEATURE:DATA:gdh:cbdbb19f-5cc3-3af2-...
# 3   Item (URN:FEATURE:DATA:gdh:0811550e-7f8a-3582-...
# 4   Item (URN:FEATURE:DATA:gdh:219ec988-7c8f-3fac-...
# ..                                                ...
# 75  Item (URN:FEATURE:DATA:gdh:4c758d19-7362-3e27-...
# 76  Item (URN:FEATURE:DATA:gdh:59d3bc97-c0e2-308d-...
# 77  Item (URN:FEATURE:DATA:gdh:8c9455d5-9faf-31bc-...
# 78  Item (URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-...
# 79  Item (URN:FEATURE:DATA:gdh:0939f7e3-f40e-31c9-...
#
#                                              geometry
# 0   POLYGON ((96.19312 16.26222, 96.20672 15.27075...
# 1   POLYGON ((103.08352 45.94729, 103.83596 45.959...
# 2   POLYGON ((101.5455 38.79789, 101.59209 37.8101...
# 3   POLYGON ((101.24793 37.02528, 101.21947 36.036...
# 4   POLYGON ((107.79861 47.73874, 107.80285 47.819...
# ..                                                ...
# 75  POLYGON ((104.99971 51.04807, 104.99972 50.463...
# 76  POLYGON ((101.45454 40.5964, 101.50549 39.6090...
# 77  POLYGON ((114.81208 65.80592, 114.89231 64.821...
# 78  POLYGON ((101.43771 40.90608, 101.45918 40.508...
# 79  POLYGON ((111.06215 54.14751, 109.46869 54.138...
#
# [80 rows x 32 columns]

# %% [markdown]
# ## Providing an api key
# The next parts involve requests that require an api-key. You can register one using the following method. We will also set a default download directory, for later. We use a file `config.json` formed as follows :
#
# ```json
# {"api_key" : "MyApiKey","download_dir" : "/tmp"}
# ```

# %%
from pygeodes import Config

conf = Config.from_file("config.json")
geodes.set_conf(conf)

# %% [markdown]
# Other ways to configure pygeodes are described in [configuration](configuration.rst).

# %% [markdown]
# ## Quicklook
# Now we can have a look at our items.

# %%
for item in filtered["item"]:
    print(f"Quicklook of {item}")
    item.show_quicklook()
# Out:
# Quicklook of Item (URN:FEATURE:DATA:gdh:ccd73d19-4604-3d80-8bd6-88e4067cb916:V1)
# /work/scratch/data/robertm/dev/env_tmp/pygeodes_cible/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %% [markdown]
# ## Downloading items

# %% [markdown]
# Now we could want to download these items for further use :

# %%
for item in filtered["item"]:
    item.download_archive()
# Out:
# /work/scratch/data/robertm/dev/env_tmp/pygeodes_cible/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'geodes-portal.cnes.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Download completed at /work/scratch/data/robertm/dev/pygeodes/docs/source/user_guide/S2C_MSIL1C_20260215T035841_N0512_R004_T48TTL_20260215T055156.zip

# %% [markdown]
# As we provided `/tmp` as default download dir, the downloads are stored in this folder.
